# %% [markdown]
# #Movie Recommendation Engine
# Using Cosine Similarity to Build a Movie Recommendation System: Based on a movie the user chose before, this program recommands new movies and Tv shows to the liking of the user

# %% [markdown]
# # Task 1 Import the libraries

# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
# helper functions

def get_title_from_index(index):
    return df[df.index==index]["title"].values[0]

def get_index_from_title(title):
    return df[df.title==title]["index"].values[0]

# %% [markdown]
# #Task 2 :import dataset

# %%
df =pd.read_csv("movie_dataset.csv")
#print(df)

# %% [markdown]
# #Task 3: select features

# %%
features=['keywords','cast','genres','director']

# %% [markdown]
# #Task 4: Create column to combine features

# %%
# getting rid of all the NAN values 
for feature in features:
    df[feature]=df[feature].fillna('')

def combine_features(row):
    return row['keywords']+" "+row['cast']+" "+row['genres']+" "+row['director']
df["combine_features"]=df.apply(combine_features,axis=1)

#print(df["combine_features"].head())

# %% [markdown]
# #Task 5: Create count matrix

# %%
cv=CountVectorizer()

count_matrix=cv.fit_transform(df["combine_features"])
#print (count_matrix.toarray())

# %% [markdown]
# #Task 6 : Cosine similarity

# %%
cosine_sim = cosine_similarity(count_matrix)
#print (cosine_sim)

movie_user_likes="Sheena" #the choice u made before, the one we're building on

# %% [markdown]
# #Task 7:  get index of movie

# %%
movie_index=get_index_from_title(movie_user_likes)

similar_movies=list(enumerate(cosine_sim[movie_index]))

# %% [markdown]
# #Task 8 : Get a list of similar movies

# %%
sorted_similar_movies=sorted(similar_movies,key=lambda x:x[1],reverse=True)
print(sorted_similar_movies)
# Out:
# [(1932, 0.9999999999999997), (4401, 0.3779644730092272), (1086, 0.35714285714285704), (238, 0.3086066999241838), (420, 0.27583864218368526), (1192, 0.27153769332085226), (618, 0.27003086243366087), (1586, 0.27003086243366087), (1827, 0.27003086243366087), (2826, 0.27003086243366087), (1296, 0.26726124191242434), (426, 0.264575131106459), (1155, 0.264575131106459), (3184, 0.264575131106459), (3993, 0.26013299085723596), (102, 0.2594372608313854), (410, 0.2594372608313854), (661, 0.2594372608313854), (778, 0.2594372608313854), (784, 0.2594372608313854), (1078, 0.2594372608313854), (1230, 0.2594372608313854), (1686, 0.2594372608313854), (2046, 0.2594372608313854), (59, 0.2545875386086578), (72, 0.2545875386086578), (1277, 0.25354627641855493), (1191, 0.24999999999999992), (1077, 0.24743582965269678), (1918, 0.24743582965269678), (1344, 0.2456518422202587), (71, 0.24397501823713325), (52, 0.24174688920761403), (350, 0.24174688920761403), (732, 0.24174688920761403), (1083, 0.2417468892076
# ...

# %% [markdown]
# #Task 9: Print titles of first 50 movies

# %%
i=0
for element in sorted_similar_movies:
		print (get_title_from_index(element[0]))
		i=i+1
		if i>50:
			break
# Out:
# Sheena
# The Helix... Loaded
# Aliens in the Attic
# Teenage Mutant Ninja Turtles
# Hellboy II: The Golden Army
# Spawn
# Mystery Men
# A View to a Kill
# Teenage Mutant Ninja Turtles II: The Secret of the Ooze
# Time Bandits
# Superman III
# The Hunger Games
# Spy Kids 3-D: Game Over
# The Ice Pirates
# Journey to Saturn
# The Hunger Games: Mockingjay - Part 2
# Mirror Mirror
# Zathura: A Space Adventure
# Meet Dave
# In the Name of the King: A Dungeon Siege Tale
# The Ant Bully
# The Shadow
# The Borrowers
# RoboCop 3
# 2012
# Suicide Squad
# Delgo
# Small Soldiers
# Johnny English
# Big Trouble in Little China
# Hot Tub Time Machine
# The Mummy: Tomb of the Dragon Emperor
# Transformers: Dark of the Moon
# Charlie's Angels
# Paycheck
# Babylon A.D.
# Southland Tales
# 30 Minutes or Less
# The Fifth Element
# Titan A.E.
# Underworld: Rise of the Lycans
# Into the Blue
# The Amazing Spider-Man
# Jupiter Ascending
# Puss in Boots
# Monkeybone
# Hook
# ...
